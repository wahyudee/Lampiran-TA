# %%
import pandas as pd
  
TWEET_DATA = pd.read_excel("DATASET_BEFORE.xlsx")
TWEET_DATA.head(10)
# Out:
#                                                tweet  sentimen
# 0  @safira_floran @Dennysiregar7 @AnnisaPohan @Ra...  Negative
# 1  @princelippeu @kimlipssi @lyelovin Nawww she l...  Negative
# 2  omnibus law di demo ini gaada yg mau demo ppkm...  Negative
# 3  Katanya omnibus law, buat mempersingkat undang...  Negative
# 4  @e100ss Koyo demo omnibus law.Apa artine gak o...  Positive
# 5  @alisyarief Mungkin itu mrk masukkan ke UU sap...  Positive
# 6  Omnibus Law cegah korupsi di birokrasi https:/...  Positive
# 7  @msaid_didu Gimana cara Sri Mulyani cs...bikin...  Negative
# 8  Sdh dirancang jauh2 hari, bahkan sejak dikelua...  Positive
# 9  Omnibus Law cegah korupsi di Birokrasi. https:...  Positive

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].str.lower()


print('Case Folding Result : \n')
TWEET_DATA.head(10)
# Out:
# Case Folding Result :
#                                                tweet  sentimen
# 0  @safira_floran @dennysiregar7 @annisapohan @ra...  Negative
# 1  @princelippeu @kimlipssi @lyelovin nawww she l...  Negative
# 2  omnibus law di demo ini gaada yg mau demo ppkm...  Negative
# 3  katanya omnibus law, buat mempersingkat undang...  Negative
# 4  @e100ss koyo demo omnibus law.apa artine gak o...  Positive
# 5  @alisyarief mungkin itu mrk masukkan ke uu sap...  Positive
# 6  omnibus law cegah korupsi di birokrasi https:/...  Positive
# 7  @msaid_didu gimana cara sri mulyani cs...bikin...  Negative
# 8  sdh dirancang jauh2 hari, bahkan sejak dikelua...  Positive
# 9  omnibus law cegah korupsi di birokrasi. https:...  Positive

# %%
import string 
import re #regex library

# %%
# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# %%
# ------ Tokenizing ---------

def remove_tweet_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_tweet_special)

# %%
#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_whitespace_multiple)

# %%
# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

TWEET_DATA['tweet'] = TWEET_DATA['tweet'].apply(remove_singl_char)

# %%
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

TWEET_DATA['tweet_tokens'] = TWEET_DATA['tweet'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(TWEET_DATA['tweet_tokens'].head(10))
# Out:
# Tokenizing Result :
#
# 0    [floran, sedang, latihan, menghapus, omnibus, ...
# 1    [nawww, she, literally, said, ngapain, demo, s...
# 2    [omnibus, law, di, demo, ini, gaada, yg, mau, ...
# 3    [katanya, omnibus, law, buat, mempersingkat, u...
# 4    [koyo, demo, omnibus, lawapa, artine, gak, ono...
# 5    [mungkin, itu, mrk, masukkan, ke, uu, sapujaga...
# 6        [omnibus, law, cegah, korupsi, di, birokrasi]
# 7    [didu, gimana, cara, sri, mulyani, csbikin, in...
# 8    [sdh, dirancang, jauh, hari, bahkan, sejak, di...
# 9        [omnibus, law, cegah, korupsi, di, birokrasi]
# Name: tweet_tokens, dtype: object

# %%
# NLTK calc frequency distribution
def freqDist_wrapper(text):
    return FreqDist(text)

TWEET_DATA['tweet_tokens_fdist'] = TWEET_DATA['tweet_tokens'].apply(freqDist_wrapper)

print('Frequency Tokens : \n') 
TWEET_DATA.head(10)
# Out:
# Frequency Tokens :
#                                                tweet  sentimen  \
# 0  floran sedang latihan menghapus omnibus law dg...  Negative
# 1  nawww she literally said ngapain demo sih biki...  Negative
# 2  omnibus law di demo ini gaada yg mau demo ppkm...  Negative
# 3  katanya omnibus law buat mempersingkat undangu...  Negative
# 4  koyo demo omnibus lawapa artine gak onok sing ...  Positive
# 5  mungkin itu mrk masukkan ke uu sapujagad yg td...  Positive
# 6             omnibus law cegah korupsi di birokrasi  Positive
# 7  didu gimana cara sri mulyani csbikin ini grafi...  Negative
# 8  sdh dirancang jauh hari bahkan sejak dikeluark...  Positive
# 9             omnibus law cegah korupsi di birokrasi  Positive
#
#                                         tweet_tokens  \
# 0  [floran, sedang, latihan, menghapus, omnibus, ...
# 1  [nawww, she, literally, said, ngapain, demo, s...
# 2  [omnibus, law, di, demo, ini, gaada, yg, mau, ...
# 3  [katanya, omnibus, law, buat, mempersingkat, u...
# 4  [koyo, demo, omnibus, lawapa, artine, gak, ono...
# 5  [mungkin, itu, mrk, masukkan, ke, uu, sapujaga...
# 6      [omnibus, law, cegah, korupsi, di, birokrasi]
# 7  [didu, gimana, cara, sri, mulyani, csbikin, in...
# 8  [sdh, dirancang, jauh, hari, bahkan, sejak, di...
# 9      [omnibus, law, cegah, korupsi, di, birokrasi]
#
#                                   tweet_tokens_fdist
# 0  {'floran': 1, 'sedang': 1, 'latihan': 1, 'meng...
# 1  {'nawww': 1, 'she': 1, 'literally': 1, 'said':...
# 2  {'omnibus': 1, 'law': 1, 'di': 1, 'demo': 2, '...
# 3  {'katanya': 1, 'omnibus': 1, 'law': 1, 'buat':...
# 4  {'koyo': 1, 'demo': 1, 'omnibus': 1, 'lawapa':...
# 5  {'mungkin': 1, 'itu': 1, 'mrk': 1, 'masukkan':...
# 6  {'omnibus': 1, 'law': 1, 'cegah': 1, 'korupsi'...
# 7  {'didu': 1, 'gimana': 1, 'cara': 2, 'sri': 1, ...
# 8  {'sdh': 1, 'dirancang': 1, 'jauh': 1, 'hari': ...
# 9  {'omnibus': 1, 'law': 1, 'cegah': 1, 'korupsi'...

# %%
from nltk.corpus import stopwords

# %%
# stopword
list_stopwords = stopwords.words('indonesian')

# %%
# ---------------------------- stopword manual  ------------------------------------
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# %%
# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_excel("kbba.xlsx", names= ["stopword"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopword"][0].split(' '))

# %%
# convert list to dictionary
list_stopwords = set(list_stopwords)

# %%
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

TWEET_DATA['tweet_tokens_WSW'] = TWEET_DATA['tweet_tokens'].apply(stopwords_removal) 


print(TWEET_DATA['tweet_tokens_WSW'].head(10))
TWEET_DATA.head(10)
# Out:
# 0    [floran, latihan, menghapus, omnibus, law, mem...
# 1    [nawww, she, literally, said, ngapain, demo, s...
# 2      [omnibus, law, demo, gaada, demo, ppkm, minggu]
# 3    [omnibus, law, mempersingkat, undangundang, la...
# 4    [koyo, demo, omnibus, lawapa, artine, onok, si...
# 5    [mrk, masukkan, uu, sapujagad, diganggu, gugat...
# 6            [omnibus, law, cegah, korupsi, birokrasi]
# 7    [didu, gimana, sri, mulyani, csbikin, grafik, ...
# 8    [dirancang, dikeluarkannya, keputusan, perppu,...
# 9            [omnibus, law, cegah, korupsi, birokrasi]
# Name: tweet_tokens_WSW, dtype: object
#                                                tweet  sentimen  \
# 0  floran sedang latihan menghapus omnibus law dg...  Negative
# 1  nawww she literally said ngapain demo sih biki...  Negative
# 2  omnibus law di demo ini gaada yg mau demo ppkm...  Negative
# 3  katanya omnibus law buat mempersingkat undangu...  Negative
# 4  koyo demo omnibus lawapa artine gak onok sing ...  Positive
# 5  mungkin itu mrk masukkan ke uu sapujagad yg td...  Positive
# 6             omnibus law cegah korupsi di birokrasi  Positive
# 7  didu gimana cara sri mulyani csbikin ini grafi...  Negative
# 8  sdh dirancang jauh hari bahkan sejak dikeluark...  Positive
# 9             omnibus law cegah korupsi di birokrasi  Positive
#
#                                         tweet_tokens  \
# 0  [floran, sedang, latihan, menghapus, omnibus, ...
# 1  [nawww, she, literally, said, ngapain, demo, s...
# 2  [omnibus, law, di, demo, ini, gaada, yg, mau, ...
# 3  [katanya, omnibus, law, buat, mempersingkat, u...
# 4  [koyo, demo, omnibus, lawapa, artine, gak, ono...
# 5  [mungkin, itu, mrk, masukkan, ke, uu, sapujaga...
# 6      [omnibus, law, cegah, korupsi, di, birokrasi]
# 7  [didu, gimana, cara, sri, mulyani, csbikin, in...
# 8  [sdh, dirancang, jauh, hari, bahkan, sejak, di...
# 9      [omnibus, law, cegah, korupsi, di, birokrasi]
#
#                                   tweet_tokens_fdist  \
# 0  {'floran': 1, 'sedang': 1, 'latihan': 1, 'meng...
# 1  {'nawww': 1, 'she': 1, 'literally': 1, 'said':...
# 2  {'omnibus': 1, 'law': 1, 'di': 1, 'demo': 2, '...
# 3  {'katanya': 1, 'omnibus': 1, 'law': 1, 'buat':...
# 4  {'koyo': 1, 'demo': 1, 'omnibus': 1, 'lawapa':...
# 5  {'mungkin': 1, 'itu': 1, 'mrk': 1, 'masukkan':...
# 6  {'omnibus': 1, 'law': 1, 'cegah': 1, 'korupsi'...
# 7  {'didu': 1, 'gimana': 1, 'cara': 2, 'sri': 1, ...
# 8  {'sdh': 1, 'dirancang': 1, 'jauh': 1, 'hari': ...
# 9  {'omnibus': 1, 'law': 1, 'cegah': 1, 'korupsi'...
#
#                                     tweet_tokens_WSW
# 0  [floran, latihan, menghapus, omnibus, law, mem...
# 1  [nawww, she, literally, said, ngapain, demo, s...
# 2    [omnibus, law, demo, gaada, demo, ppkm, minggu]
# 3  [omnibus, law, mempersingkat, undangundang, la...
# 4  [koyo, demo, omnibus, lawapa, artine, onok, si...
# 5  [mrk, masukkan, uu, sapujagad, diganggu, gugat...
# 6          [omnibus, law, cegah, korupsi, birokrasi]
# 7  [didu, gimana, sri, mulyani, csbikin, grafik, ...
# 8  [dirancang, dikeluarkannya, keputusan, perppu,...
# 9          [omnibus, law, cegah, korupsi, birokrasi]

# %%
normalizad_word = pd.read_excel("kbba.xlsx")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

TWEET_DATA['tweet_normalized'] = TWEET_DATA['tweet_tokens_WSW'].apply(normalized_term)

TWEET_DATA['tweet_normalized'].head(10)
# Out:
# 0    [floran, latihan, menghapus, omnibus, law, mem...
# 1    [nawww, she, literally, said, sedang apa, demo...
# 2    [omnibus, law, demo, tidak ada uang, demo, ppk...
# 3    [omnibus, law, mempersingkat, undangundang, la...
# 4    [koyo, demo, omnibus, lawapa, artine, onok, si...
# 5    [mrk, masukkan, uu, sapujagad, diganggu, gugat...
# 6            [omnibus, law, cegah, korupsi, birokrasi]
# 7    [didu, bagaimana, sri, mulyani, csbikin, grafi...
# 8    [dirancang, dikeluarkannya, keputusan, perppu,...
# 9            [omnibus, law, cegah, korupsi, birokrasi]
# Name: tweet_normalized, dtype: object

# %%
# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in TWEET_DATA['tweet_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

TWEET_DATA['tweet_tokens_stemmed'] = TWEET_DATA['tweet_normalized'].swifter.apply(get_stemmed_term)
print(TWEET_DATA['tweet_tokens_stemmed'])
# Out:
# 3019
# ------------------------
# floran : floran
# latihan : latih
# menghapus : hapus
# omnibus : omnibus
# law : law
# memblokir : blokir
# netizen : netizen
# wkwkwkkk : wkwkwkkk
# nawww : nawww
# she : she
# literally : literally
# said : said
# sedang apa : sedang apa
# demo : demo
# susah : susah
# orang : orang
# kerja : kerja
# during : during
# protest : protest
# cant : cant
# read : read
# the : the
# fuckkng : fuckkng
# room : room
# tidak ada uang : tidak ada uang
# ppkm : ppkm
# minggu : minggu
# mempersingkat : singkat
# undangundang : undangundang
# lakok : lakok
# kesini : kesini
# kabeh : kabeh
# undangi : undang
# entok : entok
# berkat : berkat
# ogak : ogak
# kui : kui
# ngko : ngko
# perpanjang : panjang
# karyawan : karyawan
# wajib : wajib
# strp : strp
# kantor : kantor
# pusat : pusat
# perbelanjaan : belanja
# tutup : tutup
# rakyat : rakyat
# ganti : ganti
# wna : wna
# koyo : koyo
# lawapa : lawapa
# artine : artine
# onok : onok
# sing : sing
# weruhyo : weruhyo
# mek : mek
# ngrusaki : ngrusaki
# taman : taman
# ikuw : ikuw
# mrk : mrk
# masukkan : masuk
# uu : uu
# sapujagad : sapujagad
# diganggu : ganggu
# gugat : gugat
# cegah : cegah
# korupsi : korupsi
# birokrasi : birokrasi
# didu : didu
# bagaimana : bagaimana
# sri : sri
# mulyani : mulyani
# csbikin : csbikin
# grafik : grafik
# melandai : landai
# menjadikan : jadi
# vaksin : vaksin
# dijual : jual
# bubarkan : bubar
# fpi : fpi
# penjarakan : penjara
# ibhrs : ibhrs
# bunuh : bunuh
# remaja : remaja
# pengawal : awal
# rombongan : rombong
# habib : habib
# nambah : nambah
# hutang : hutang
# dirancang : rancang
# dikeluarkannya : keluar
# keputusan : putus
# perppu : perppu
# nomor : nomor
# th : th
# corona : corona
# dimana : mana
# perpres : pres
# kedudukannya : duduk
# diatas : atas
# ngaco : ngaco
# negeri : negeri
# halah : halah
# ngantor : ngantor
# kerjanya : kerja
# buktinya : bukti
# aspirasi : aspirasi
# diperjuangkan : juang
# dpr : dpr
# ite : ite
# kpk : kpk
# uud : uud
# tho : tho
# anggota : anggota
# bobo : bobo
# manis : manis
# deh : deh
# rumah : rumah
# gedu : gedu
# bahas : bahas
# ruu : ruu
# pks : pks
# diskusi : diskusi
# belajar : ajar
# sejarah : sejarah
# terbentuknya : bentuk
# britania : britania
# raya : raya
# agama : agama
# politik : politik
# negara : negara
# indonesia : indonesia
# jr : jr
# pasal : pasal
# mas : mas
# diultra : ultra
# petita : petita
# pry : pry
# bantu : bantu
# kasih : kasih
# konteks : konteks
# salah : salah
# promotor : promotor
# cipta : cipta
# kadin : kadin
# keberpiha : keberpiha
# terpenting : penting
# mengkritik : kritik
# konsistensi : konsistensi
# integritas : integritas
# oposisi : oposisi
# bertemu : temu
# mahasiswa : mahasiswa
# kritikus : kritikus
# pemerintah : perintah
# mengesahkan : kesah
# azhar : azhar
# dejavu : dejavu
# seperti : seperti
# begitu : begitu
# ngomong-ngomong : ngomong-ngomong
# bgm : bgm
# iwan : iwan
# sumule : sumule
# uji : uji
# materi : materi
# turunannya : turun
# gilak : gilak
# dari : dari
# burden : burden
# sharing : sharing
# diperkuat : kuat
# konstitusional : konstitusional
# majelis : majelis
# papua : papua
# barat : barat
# lembaga : lembaga
# representatif : representatif
# resmi : resmi
# tolak : tolak
# pembahasan : bahas
# otsus : otsus
# jalan : jalan
# kebut : kebut
# ri : ri
# pemerinth : pemerinth
# last : last
# tweet : tweet
# bicara : bicara
# protes : protes
# dukung : dukung
# cia : cia
# kingkin : kingkin
# anida : anida
# bebas : bebas
# penjara : penjara
# terkait : kait
# menyiarkan : siar
# kabar : kabar
# tol : tol
# people : people
# talk : talk
# dorong : dorong
# raja : raja
# industri : industri
# digital : digital
# baca : baca
# selengkapnya : lengkap
# inget : inget
# heboh : heboh
# sm : sm
# ditunda : tunda
# ujungnya : ujung
# disyahkan : syah
# modus : modus
# mukidis : mukidis
# era : era
# tu : tu
# riot : riot
# jugak : jugak
# malaysian : malaysian
# kena : kena
# kerah : kerah
# kapitalis : kapitalis
# nak : nak
# pikir : pikir
# kali : kali
# taknak : taknak
# susahkan : susah
# taktau : taktau
# lah : lah
# mcm : mcm
# ini : ini
# penat : penat
# pemimpin : pimpin
# dok : dok
# jaga : jaga
# perut : perut
# tauke : tauke
# je : je
# kakak : kakak
# manik : manik
# ketua : ketua
# bem : bem
# ui : ui
# sempat : sempat
# ramai : ramai
# ugm : ugm
# agung : agung
# menunggu : tunggu
# hasil : hasil
# eh : eh
# wajar : wajar
# yak : yak
# crewet : crewet
# dibyr : dibyr
# pakai : pakai
# uang : uang
# aneh : aneh
# smpai : smpai
# nusantara : nusantara
# tapi : tapi
# ngk : ngk
# gubris : gubris
# wakil : wakil
# egois : egois
# kayak : kayak
# tidak : tidak
# malu : malu
# serius : serius
# menyelesaikan : selesai
# mintalah : minta
# bantuan : bantu
# revisi : revisi
# kolaborasi : kolaborasi
# dengarkan : dengar
# suara : suara
# keberpihakannya : pihak
# nonsense : nonsense
# sentalsentil : sentalsentil
# memang : memang
# kondisi : kondisi
# pandemi : pandemi
# hah : hah
# matiin : matiin
# mik : mik
# dewan : dewan
# setuju : tuju
# lagi : lagi
# memprotes : protes
# kaya : kaya
# waku : waku
# dibilang : bilang
# bang : bang
# fahri : fahri
# berkaca : kaca
# dapat : dapat
# arahan : arah
# partai : partai
# saran : saran
# kewenangan : wenang
# masyarakat : masyarakat
# menarik : tarik
# wakilnya : wakil
# kursi : kursi
# dprdprd : dprdprd
# ngeyel : ngeyel
# rejim : rejim
# rekam : rekam
# jejaknya : jejak
# sah : sah
# pelayan : layan
# cukong : cukong
# pemodal : modal
# tabiatnya : tabiat
# teatrikal : teatrikal
# bgmnaa : bgmnaa
# ceritanya : cerita
# diarep : diarep
# selamatkan : selamat
# nyawa : nyawa
# jakarta : jakarta
# getol : getol
# berbayar : bayar
# inisiasi : inisiasi
# masukanny : masukanny
# dimintain : dimintain
# masukan : masuk
# melulu : melulu
# kegencet : gencet
# hidup : hidup
# dimari : mari
# bu : bu
# pada : pada
# digubris : gubris
# memaksakan : paksa
# kehendaknya : hendak
# hanya : hanya
# didengar : dengar
# pemilihan umum : pilih umum
# kader : kader
# pdip : pdip
# sby : sby
# mundur : mundur
# jumhur : jumhur
# hidayat : hidayat
# langsung : langsung
# ditangkap : tangkap
# miris : miris
# banget : banget
# demokrasi : demokrasi
# rezim : rezim
# peraturan : atur
# perundangan : undang
# merugikan : rugi
# kritikan : kritik
# dibalas : balas
# tindakan : tindak
# represif : represif
# aparattak : aparattak
# percaya : percaya
# lihat : lihat
# minerba : minerba
# moel : moel
# lalatnya : lalat
# istana : istana
# lupa : lupa
# aparat : aparat
# kuat : kuat
# gol : gol
# orangorang : orangorang
# giliran : gilir
# begini : begini
# ngajakngajak : ngajakngajak
# diemdiem : diemdiem
# laksono : laksono
# politikus : politikus
# ngajak : ngajak
# bersatu : satu
# nulis : nulis
# katakata : katakata
# mutiara : mutiara
# bangkrut : bangkrut
# sen : sen
# jaman : jaman
# narasi : narasi
# sudah : sudah
# paham : paham
# intern : intern
# perusahaan : usaha
# organisasi : organisasi
# goks : goks
# korban : korban
# wkwkwkwk : wkwkwkwk
# mrjn : mrjn
# globalis : global
# lewat : lewat
# farmasi : farmasi
# punya : punya
# agenda : agenda
# jualan : jual
# mnciptakan : mnciptakan
# pandemiglobalis : pandemiglobalis
# kolonialisasi : kolonial
# sebuah : buah
# perang : perang
# pabrik : pabrik
# senjata : senjata
# alutsistaglobalis : alutsistaglobalis
# perbudakan : budak
# ojol : ojol
# outsourcing : outsourcing
# pyu : pyu
# sunarno : sunarno
# penentuan : tentu
# upah : upah
# pertarungan : tarung
# klas : klas
# pekerja : kerja
# vs : vs
# kaum : kaum
# modal : modal
# pengupahan : upah
# kotakabp : kotakabp
# lebar : lebar
# kemarin : kemarin
# twk : twk
# efek : efek
# berjalan : jalan
# cilaka : cilaka
# sesungguhnya : sungguh
# harus : harus
# profesional : profesional
# oligarki : oligarki
# pergi : pergi
# dokter : dokter
# terangan : terang
# dulung : dulung
# kerumunan : kerumun
# tetap : tetap
# salahin : salahin
# pemilihan kepala daerah : pilih kepala daerah
# dan sebagainya : dan bagai
# juga : juga
# artis : artis
# gtu : gtu
# sama : sama
# liburan : libur
# klean : klean
# bajingan : bajing
# puan : puan
# maharani : maharani
# bali : bal
# disambut : sambut
# renon : renon
# kotakabprovinsinasional : kotakabprovinsinasional
# lumpuh : lumpuh
# berdaya : daya
# pulang pergi : pulang pergi
# cilakapp : cilakapp
# turunanya : turunanya
# rumahmu : rumah
# malam : malam
# sepakat : sepakat
# melanjutkan : lanjut
# besa : besa
# saya : saya
# lawyer : lawyer
# lembur : lembur
# gadapet : gadapet
# kangen : kangen
# bangett : bangett
# pas : pas
# jamannya : jaman
# pengesahan : kesah
# insiden : insiden
# mematikan : mati
# mic : mic
# sidang : sidang
# paripurna : paripurna
# nasibnya : nasib
# seknasri : seknasri
# suruh : suruh
# ngecek : ngecek
# draft : draft
# final : final
# hasilnya : hasil
# acakan : acak
# diteruskan : terus
# tertanda : tanda
# presiden : presiden
# bilangnya : bilang
# keberatan : berat
# buruh : buruh
# mangkir : mangkir
# yok : yok
# repeat : repeat
# after : after
# me : me
# ketenagakerjaan : ketenagakerjaan
# produk : produk
# korporatokrasi : korporatokrasi
# alhamdulillah : alhamdulillah
# wni : wni
# pulang : pulang
# wuhan : wuhan
# diobservasi : observasi
# hari : hari
# natuna : natuna
# dinyatakan : nyata
# brsh : brsh
# dalam : dalam
# kelakarnya : kelakar
# menko : menko
# dibikin : bikin
# prof : prof
# gara : gara
# disahkan : sah
# covid : covid
# gampang : gampang
# masuk : masuk
# sahkan : sahkan
# virus : virus
# mudah : mudah
# datangnya : datang
# sosialisasi : sosialisasi
# ranah : ranah
# internasional : internasional
# peran : peran
# army : army
# gerakannya : gera
# saspeng : saspeng
# gegara : gegara
# ht : ht
# anjing : anjing
# lapangan : lapang
# olclk : olclk
# pakar : pakar
# hukum : hukum
# pemerhati : perhati
# bisnis : bisnis
# menguntun : untun
# beneran : beneran
# bun : bun
# wkwkwk : wkwkwk
# username : username
# berkumpul : kumpul
# private message : private message
# nyolot : nyolot
# woiiii : woiiii
# becus : becus
# kamu : kamu
# eneg : eneg
# kalangan : kalang
# rentan : rentan
# ciptaker : ciptaker
# dan seterusnya : dan terus
# kunjung : kunjung
# disahkannya : sah
# kspi : kspi
# menyerukan : seru
# kehilangan : hilang
# strategi : strategi
# melawan : lawan
# mendorong : dorong
# umkm : umkm
# berinovasi : inovasi
# menguntungkan : untung
# disetujui : tuju
# ditentang : tentang
# serikatserikat : serikatserikat
# bisu : bisu
# pembentukan : bentuk
# sejahtera : sejahtera
# sengsara : sengsara
# dinda : dinda
# aisyah : aisyah
# fathia : fathia
# rahma : rahma
# denger : denger
# china : china
# ketemuan : ketemu
# bos : bos
# batu : batu
# bara : bara
# staff : staff
# eksekutif : eksekutif
# jawa : jawa
# nurut : nurut
# makan : makan
# teriak : teriak
# jokowi : jokowi
# Cuma : cuma
# boneka : boneka
# nenek : nenek
# banteng : banteng
# official : official
# fspmi : fspmi
# riau : riau
# perlawanan : lawan
# berasa : asa
# sepupu : sepupu
# keponakan : keponakan
# berita : berita
# duka : duka
# senayan : senayan
# perwakilan : wakil
# dikabarkan : kabar
# berubah : ubah
# nama : nama
# pengkhianat : khianat
# seirin : seirin
# agungagungkan : agungagungkan
# tenaga : tenaga
# asing : asing
# longgar : longgar
# anak : anak
# beginii : begini
# halal : halal
# digebukin : digebukin
# alasan : alas
# perlukan : perlu
# gotong : gotong
# royong : royong
# pers : pers
# rilis : rilis
# aksi : aksi
# solidaritas : solidaritas
# australia : australia
# fakta : fakta
# kumpulan : kumpul
# garong : garong
# membahas : bahas
# memparipurnakan : paripurna
# diamdiam : diamdiam
# innalillahiini : innalillahiini
# berlakusehingga : berlakusehingga
# perijinan : perijinan
# berbelit : belit
# belit : belit
# meluas : luas
# sistem : sistem
# libur : libur
# make : make
# sense : sense
# angka : angka
# positif : positif
# menurun : turun
# musin : musin
# peningkatan : tingkat
# imbas : imbas
# hancurnya : hancur
# top : top
# satrio : satrio
# piningit : pingit
# versi : versi
# gorong : gorong
# mati : mati
# ketularan : tular
# kerjaan : kerja
# sumpahin : sumpahin
# teman : teman
# dikutuk : kutuk
# bytes : bytes
# terimakasih : terimakasih
# kosakata : kosakata
# halus : halus
# intercourse : intercourse
# tercatat : catat
# olh : olh
# bhwdi : bhwdi
# in : in
# melahirkan : lahir
# rakyatyaitu : rakyatyaitu
# rev : rev
# fecho : fecho
# rosiade : rosiade
# debat : debat
# melenggang : lenggang
# bertahan : tahan
# semrawut : semrawut
# dibanggain : dibanggain
# nur : nur
# video : video
# ruang : ruang
# rapat : rapat
# rekaman : rekam
# dapil : dapil
# kebijakan : bijak
# kebi : kebi
# mth : mth
# sikap : sikap
# irwan : irwan
# an : an
# maunya : mau
# wag : wag
# reuni : reuni
# nyantai : nyantai
# semenjak : semenjak
# ahok : ahok
# pilpres : pilpres
# sd : sd
# bawa : bawa
# tafsir : tafsir
# nuding : nuding
# hidungasyudahlah : hidungasyudahlah
# sono : sono
# baikan : baik
# ambil : ambil
# contoh : contoh
# partaimu : partai
# kontribusi : kontribusi
# undang : undang
# penangana : penangana
# andre : andre
# kebijakankebijakan : kebijakankebijakan
# atensi : atensi
# penanganan : tangan
# pemerint : pemerint
# nglad : nglad
# benar : benar
# kpps : kpps
# meninggal : tinggal
# pemilupilpres : pemilupilpres
# puluhan : puluh
# demontrans : demontrans
# menjelang : jelang
# pengumuman : umum
# protesdemo : protesdemo
# disyahkannya : syah
# aside : aside
# from : from
# possibility : possibility
# of : of
# being : being
# heard : heard
# ruginya : rugi
# mengemukakan : muka
# kekecewaan : kecewa
# labels : labels
# it : it
# is : is
# their : their
# job : job
# to : to
# keep : keep
# svt : svt
# afloat : afloat
# and : and
# that : that
# means : means
# they : they
# need : need
# cater : cater
# demands : demands
# diumpamaian : diumpamaian
# omni : omni
# syafa : syafa
# abdillahtoha : abdillahtoha
# dewa : dewa
# zeus : zeus
# bijak : bijak
# kritis : kritis
# berwawasan : wawas
# kedatangan : datang
# aseng : aseng
# sulit : sulit
# dihadapi : hadap
# melemahkan : lemah
# die : die
# mel : mel
# kebijakn : kebijakn
# tka : tka
# tiongkok : tiongkok
# ngenes : ngenes
# bansos : bansos
# pendemilagi : lagi
# jadi : jadi
# korbanelit : korbanelit
# pesta : pesta
# pora : pora
# pelemahan : lemah
# ente : ente
# diem : diem
# ndre : ndre
# ndrepercuma : ndrepercuma
# airlangga : airlangga
# hartarto : hartarto
# namamu : nama
# sebagai : bagai
# pembentuk : bentuk
# satgas : satgas
# pandemik : pandemik
# komando : komando
# omn : omn
# perizinan : izin
# barang : barang
# grup : grup
# musim : musim
# semi : semi
# gajadi : gajadi
# pengisi : isi
# ost : ost
# member : member
# tidak tahu : tidak tahu
# biasnya : bias
# selusin : lusin
# sekarang : sekarang
# hmccccc : hmccccc
# penangkapan : tangkap
# narkocoy : narkocoy
# bakri : bakri
# kaitannya : kait
# isu : isu
# tv : tv
# media : media
# bapanya : bapa
# gokar : gokar
# pedeipogokar : pedeipogokar
# bertentangan : tentang
# kesel : kesel
# moment : moment
# jarak : jarak
# pejabat : jabat
# cepetcepet : cepetcepet
# ngesahin : ngesahin
# dampak : dampak
# lingkungan : lingkung
# marginal : marginal
# dlsb : dlsb
# wr : wr
# ohhh : ohhh
# akar : akar
# penanaman : tanam
# warisan : waris
# menyempurnakan : sempurna
# zq : zq
# uupp : uupp
# agraria : agraria
# mengatur : atur
# hak : hak
# usaha : usaha
# hgu : hgu
# lahan : lahan
# korporasi : korporasi
# maks : maks
# ayat : ayat
# terus : terus
# dan lain-lain : dan lain
# banggainrakyat : banggainrakyat
# bodoh : bodoh
# aktivis : aktivis
# maklumat : maklumat
# pemuka : muka
# buka : buka
# partisipasi : partisipasi
# publik : publik
# tandatangani : tandatangani
# petisi : petisi
# id : id
# via : via
# solusi : solusi
# roundtable : roundtable
# discussion : discussion
# diselenggarakan : selenggara
# fadli : fadli
# zon : zon
# terbukti : bukti
# permasalahan : masalah
# klik : klik
# vidonya : vidonya
# ikut serta : ikut serta
# pernah : pernah
# ngirim : ngirim
# link : link
# diserang : serang
# kocak : kocak
# guenya : gue
# ramiro : ramiro
# dilarang : larang
# terbang : terbang
# kecuali : kecuali
# gagal : gagal
# my : my
# strong : strong
# hope : hope
# prayers : prayers
# goes : goes
# kalimantan : kalimantan
# papuas : papuas
# forest : forest
# ancaman : ancam
# destruksi : destruksi
# proyek : proyek
# pesan : pesan
# sahin : sahin
# selagi : selagi
# mikro : mikro
# darurat : darurat
# disko : disko
# lagu : lagu
# upstairs : upstairs
# tenang : tenang
# dipaksain : dipaksain
# larut : larut
# saturday : saturday
# night : night
# uhuk : uhuk
# sori : sori
# enak : enak
# mangkas : mangkas
# kesejahteraan : sejahtera
# meh : meh
# sumber : sumber
# gunanya : guna
# dikhianati : khianat
# menteri : menteri
# bajer : bajer
# tolong : tolong
# informasi : informasi
# nemunya : nemunya
# twitter : twitter
# bule : bule
# bayar : bayar
# billboard : billboard
# promosi : promosi
# nyempil : nyempil
# website : website
# billboardnya : billboardnya
# masker : masker
# karya : karya
# berdampak : dampak
# barubaru : barubaru
# mengirim : kirim
# ribuan : ribu
# tabung : tabung
# india : india
# menjad : menjad
# memiliki : milik
# vital : vital
# legislasi : legislasi
# periode : periode
# dinilai : nilai
# berparadigma : paradigma
# kerakyatan : rakyat
# berpihak : pihak
# baskoro : baskoro
# dalem : dalem
# miknya : mik
# dimatiin : dimatiin
# mi : mi
# kelas : kelas
# borjuis : borjuis
# menyelamatkan : selamat
# kapitalisme : kapitalisme
# krisisnya : krisis
# mari : mari
# bergabung : gabung
# tumbangkan : tumbang
# berdiri : diri
# tepi : tepi
# jurang : jurang
# rasis : ras
# alih : alih
# sektor : sektor
# pekerjaan : kerja
# phk : phk
# butuh : butuh
# woy : woy
# janji : janji
# memberikan : beri
# saja : saja
# meningkatkan : tingkat
# arus : arus
# bahaya : bahaya
# dunia : dunia
# ibas : ibas
# keselamatan : selamat
# rakyatyg : rakyatyg
# sekarat : sekarat
# istian : istian
# telatt : telatt
# woi : woi
# meluncur : luncur
# kemana : mana
# dikorupsi : korupsi
# pandemic : pandemic
# dijadikan : jadi
# ajang : ajang
# rasionalisasi : rasionalisasi
# dilemahkan : lemah
# pulau : pulau
# eksplorasi : eksplorasi
# segmen : segmen
# dibahas : bahas
# opini : opini
# guoblokk : guoblokk
# apakabar : apakabar
# avatar : avatar
# ido : ido
# bantul : bantul
# naikin : naikin
# hastag : hastag
# indo : indo
# berpendapat : dapat
# idol : idol
# rl : rl
# hubungannyaa : hubungannyaa
# buruk : buruk
# pemilik : milik
# tanah : tanah
# ulayat : ulayat
# menggenjot : genjot
# deforestasi : deforestasi
# dianggap : anggap
# hutan : hutan
# maju : maju
# psst : psst
# indokafe : indokafe
# serenceng : renceng
# murah : murah
# selamat : selamat
# bunda : bunda
# pipin : pipin
# penggiat : giat
# sosial : sosial
# kota : kota
# bengkulu : bengkulu
# sembuh : sembuh
# sakit : sakit
# menimpamu : timpa
# relawan : rawan
# gigih : gigih
# ampe : ampe
# hitung : hitung
# sendiri : sendiri
# gedean : gede
# hasilin : hasilin
# sehari : hari
# pegawai : pegawai
# segitiga : segitiga
# emas : emas
# usia : usia
# koh : koh
# kch : kch
# penguasa : kuasa
# sibuk : sibuk
# diabaikan : abai
# super : super
# duper : duper
# dampaknya : dampak
# kekami : kekam
# abang : abang
# ramli : ramli
# pesangon : sangon
# hbs : hbs
# dipangkas : pangkas
# lawpadahal : lawpadahal
# satunya : satu
# tabungan : tabung
# koko : koko
# nyusahin : nyusahin
# mikir : mikir
# aturan : atur
# mutlak : mutlak
# pendidikan : didik
# benci : benci
# adil : adil
# merekaa : merekaa
# bernaungmu : naung
# rakyatmu : rakyat
# kesemuanya : semua
# beda : beda
# kepemimpinan : pimpin
# karno : karno
# nasionalisme : nasionalisme
# disaat : saat
# tertidur : tidur
# pulas : pulas
# lelahnya : lelah
# ditengah : tengah
# suasana : suasana
# menghadiri : hadir
# musyawarah nasional : musyawarah nasional
# offline : offline
# status : status
# warna : warna
# kedaruratan : darurat
# be : be
# suami : suami
# dibolehin : dibolehin
# karyawannya : karyawannya
# ikutan : ikut
# serikat : serikat
# duluan : duluan
# diloloskan : lolos
# pencipta : cipta
# miskin : miskin
# bentang : bentang
# alam : alam
# rusak : rusak
# menilai : nilai
# cultured : cultured
# fokus : fokus
# pembangunan : bangun
# mengundang : undang
# investor : investor
# menciptakan : cipta
# inlander : inlander
# sedia : sedia
# menjilat : jilat
# diakui : aku
# sadar : sadar
# diperbudak : budak
# mendesak : desak
# dibutuhkan : butuh
# pengesahannya : kesah
# penyebab : sebab
# rs : rs
# krisis : krisis
# oksigen : oksigen
# menebar : tebar
# ilusi : ilusi
# harapan : harap
# tercapai : capai
# pondasinya : pondasinya
# md : md
# pertanggungjawaban : pertanggungjawaban
# pendemo : demo
# gimane : gimane
# penyebaran : sebar
# kopit : kopit
# ae : ae
# pesat : pesat
# kecewa : kecewa
# mengatangatai : mengatangatai
# ormas : ormas
# sentralistik : sentralistik
# paska : paska
# pemdapemda : pemdapemda
# waras : waras
# pempus : pempus
# sinting : sinting
# dihapus : hapus
# persyaratannya : syarat
# izin : izin
# pan : pan
# enggan : enggan
# po : po
# sediakan : sedia
# khusus : khusus
# lebih baik : lebih baik
# dapur : dapur
# frying : frying
# sukabumi : sukabumi
# gencar : gencar
# domino : domino
# kian : kian
# mega : mega
# bukit : bukit
# algoritma : algoritma
# jembatan : jembatan
# penghubung : hubung
# kadudampitsukalarang : kadudampitsukalarang
# ruas : ruas
# barossagarantentegalbuled : barossagarantentegalbuled
# suksesi : suksesi
# ketum : tum
# pemilihan : pilih
# arsjad : arsjad
# rasjid : rasjid
# pebi : pebi
# landasan : landas
# dipakai : pakai
# aso : aso
# argumen : argumen
# libertarian : libertarian
# gaji : gaji
# absolut : absolut
# kemahalan : mahal
# mahal : mahal
# relatif : relatif
# nilai : nilai
# oh : oh
# vietnam : vietnam
# jam : jam
# manusiawi : manusiawi
# ribu : ribu
# warga : warga
# unjuk : unjuk
# kudeta : kudeta
# militer : militer
# myanmar : myanmar
# meminjam : pinjam
# logika : logika
# hadapi : hadap
# pu : pu
# tahun : tahun
# golongan putih : golong putih
# ngarep : ngarep
# wowo : wowo
# riweuh : riweuh
# cina : cina
# lockdown : lockdown
# kalau : kalau
# budget : budget
# masih : masih
# belum : belum
# hongkongmana : hongkongmana
# melindungi : lindung
# naker : naker
# kitagk : kitagk
# berlaku : laku
# kah : kah
# ciptakerja : ciptakerja
# same : same
# case : case
# ayahku : ayah
# tersirat : sirat
# ingin : ingin
# ku : ku
# coba : coba
# jalanin : jalanin
# jalaninnya : jalaninnya
# sekedar : dar
# im : im
# love : love
# pdkt : pdkt
# vaduka : vaduka
# sumbanggiliran : sumbanggiliran
# bansosgiliran : bansosgiliran
# lawdll : lawdll
# mencekik : cekik
# rakyatmuka : rakyatmuka
# bukan : bukan
# penjilatujungnya : penjilatujungnya
# kelakuannya : laku
# sadarin : sadarin
# tanyain : tanyain
# kebanyakan : banyak
# tahu : tahu
# apa : apa
# tuntut : tuntut
# skrng : skrng
# gugatan : gugat
# kalah : kalah
# mahkamah : mahkamah
# konstitusi : konstitusi
# jawabanya : jawabanya
# containment : containment
# kacau : kacau
# balau : balau
# faskes : faskes
# kolaps : kolaps
# you : you
# name : name
# test : test
# bersikap : sikap
# campur : campur
# pra : pra
# elit : elit
# jelata : jelata
# diam : diam
# pengeboman : bom
# malioboro : malioboro
# yogya : yogya
# terbakarnya : bakar
# halte : halte
# pengusaha : usaha
# diuntungkan : untung
# digebugin : digebugin
# ditahan : tahan
# disuruh : suruh
# nyumbang : nyumbang
# digaji : gaji
# sembarangan : sembarang
# semoga : moga
# skdar : skdar
# lip : lip
# service : service
# gsp : gsp
# goal : goal
# tinggal : tinggal
# dirumah : rumah
# ye : ye
# lord : lord
# menghabisi : habis
# naiknya : naik
# pembungkaman : bungkam
# pelarangan : larang
# pendapat : dapat
# represifitas : represifitas
# meninggalnya : tinggal
# menyuarakan : suara
# dikhawatirkan : khawatir
# dipersiapkan : siap
# keuangan : uang
# simak : simak
# ayo : ayo
# aidil : aidil
# akbar : akbar
# perencana : rencana
# desentralisasi : desentralisasi
# masif : masif
# federal : federal
# ditolong : tolong
# ditinggalkan : tinggal
# kadang : kadang
# disalah : salah
# ojok : ojok
# jero : jero
# ngonolah : ngonolah
# muhammad : muhammad
# saiki : saiki
# njaluk : njaluk
# kerjasama : kerjasama
# kae : kae
# gebuk : gebuk
# kontrak : kontrak
# sekejap : kejap
# tuh : tuh
# contohnya : contoh
# hindari : hindar
# diakalinya : akal
# karantina : karantina
# ih : ih
# gedung : gedung
# ctim : ctim
# orasi : orasi
# mimpin : mimpin
# eskalasi : eskalasi
# sayang : sayang
# jahim : jahim
# jurusan : jurus
# government : government
# menjalankan : jalan
# agendanya : agenda
# dalihnya : dalih
# investasi : investasi
# sebanyaknya : banyak
# memperluas : luas
# wacana : wacana
# penolakan : tolak
# momen : momen
# terulang : ulang
# susan : sus
# mengkritisi : kritisi
# wilayah : wilayah
# rencana : rencana
# zonasi : zonasi
# pesisir : pesisir
# pulaupulau : pulaupulau
# rzwpk : rzwpk
# diterbitkan : terbit
# daerah : daerah
# sejalan : jalan
# turunan : turun
# penyelenggaraan : selenggara
# bidang : bidang
# kelautan : laut
# perikanan : ikan
# zona : zona
# inti : inti
# konservasi : konservasi
# dialihfungsikan : dialihfungsikan
# ancam : ancam
# perubahan : ubah
# kawasan : kawasan
# polemik : polemik
# dikritisi : kritisi
# rendah : rendah
# dipake : dipake
# bercandaan : canda
# menyusul : susul
# tax : tax
# amnesty : amnesty
# jilid : jilid
# ii : ii
# empati : empati
# pulak : pulak
# satusatunya : satusatunya
# terdengar : dengar
# peluncuran : luncur
# kapal : kapal
# vlcc : vlcc
# pride : pride
# prime : prime
# pertamina : pertamina
# selebihnya : lebih
# demonstrasi : demonstrasi
# lonjakan : lonjak
# pulih : pulih
# gembong : gembong
# mbacot : mbacot
# alhamdullilah : alhamdullilah
# pt : pt
# siix : siix
# batam : batam
# ngotot : ngotot
# berulang : ulang
# melanggar : langgar
# akut : akut
# kerjalah : kerja
# pemicunya : picu
# oughhh : oughhh
# polanya : pola
# diretas : retas
# dosen : dosen
# peroranganxd : peroranganxd
# membuahkan : buah
# terorganisir : organisir
# reformasi : reformasi
# pergerakan : gera
# sifatnya : sifat
# sporadis : sporadis
# kadangc : kadangc
# nyata : nyata
# adat : adat
# perampasan : ampas
# sedari : dar
# dilegalkan : legal
# sapu : sapu
# jagat : jagat
# besarbesaran : besarbesaran
# lnjutxd : lnjutxd
# xd : xd
# adatperampasan : adatperampasan
# adatlahan : adatlahan
# adatyg : adatyg
# duluseolah : duluseolah
# tersebutdemonstrasi : tersebutdemonstrasi
# kalanganxd : kalanganxd
# mengurus : urus
# basic : basic
# ngak : ngak
# mimpi : mimpi
# langit : langit
# newscom : newscom
# konflik : konflik
# keberadaan : ada
# memperdalam : dalam
# tengahtengah : tengahtengah
# perkotaan : kota
# mengalami : alami
# muslimahnews : muslimahnews
# lantas : lantas
# permasalahannya : masalah
# pandangan : pandang
# islam : islam
# asmara : asmara
# pokoknya : pokok
# partai politik : partai politik
# pendukung : dukung
# diperparah : parah
# dizaman : zaman
# merugika : merugika
# petani : tani
# berhenti : henti
# pembenaran : benar
# kawal : kawal
# formil : formil
# kibarkan : kibar
# bendera : bendera
# merah : merah
# putih : putih
# seribu : ribu
# fun : fun
# fact : fact
# cobra : cobra
# consolidated : consolidated
# reconciliation : reconciliation
# act : act
# became : became
# april : april
# achmadi : achmadi
# prestasinya : prestasi
# meloloskan : lolos
# prestasi : prestasi
# besok : besok
# sekian : sekian
# bermasalah : masalah
# busuk : busuk
# kapitalismeoligarki : kapitalismeoligarki
# sejatinya : sejati
# siste : siste
# ale : ale
# namanya : nama
# pemutusan : putus
# dipecat : pecat
# diphk : diphk
# dsna : dsna
# dulu : dulu
# besarn : besarn
# bbgai : bbgai
# tersebutxd : tersebutxd
# milik : milik
# masyarakatxd : masyarakatxd
# breaking : breaking
# dominion : dominion
# tries : tries
# bending : bending
# get : get
# its : its
# way : way
# with : with
# atlantic : atlantic
# coast : coast
# pipeline : pipeline
# tucking : tucking
# provision : provision
# into : into
# riset : riset
# menempatkan : tempat
# iklim : iklim
# mengkhawatirkan : khawatir
# berdampingan : damping
# melestarikan : lestari
# cepat : cepat
# indonesian : indonesian
# currently : currently
# taken : taken
# rule : rule
# which : which
# socalled : socalled
# widely : widely
# attracting : attracting
# palm : palm
# oil : oil
# investors : investors
# many : many
# those : those
# who : who
# have : have
# been : been
# exploiting : exploiting
# west : west
# come : come
# korea : korea
# estimated : estimated
# more : more
# than : than
# hectares : hectares
# forcefully : forcefully
# controlled : controlled
# by : by
# terbuktiaturan : terbuktiaturan
# menyengsarakan : sengsara
# rakyatnyatermasuk : rakyatnyatermasuk
# taunya : tau
# dengar : dengar
# we : we
# gang : gang
# gangxd : gangxd
# nemu : nemu
# live : live
# jamnya : jam
# youtube : youtube
# mentor : mentor
# kokoryaanku : kokoryaanku
# sukakartsy : sukakartsy
# position : position
# fictitious : fictitious
# positive : positive
# administrative : administrative
# decisions : decisions
# as : as
# dispute : dispute
# object : object
# state : state
# court : court
# perspectivexd : perspectivexd
# know : know
# visit : visit
# salty : salty
# pertanian : tani
# administrasijago : administrasijago
# ajak : ajak
# koperasixd : koperasixd
# syarat : syarat
# pendirian : diri
# koperasi : koperasi
# demodemo : demodemo
# dprd : dprd
# berhubungan : hubung
# institusi : institusi
# struktur : struktur
# membungkam : bungkam
# kritik : kritik
# mantunya : mantu
# nyalon : nyalon
# pengistimewaan : istimewa
# penegak : tegak
# awas : awas
# serentak : serentak
# nasional : nasional
# batalkan : batal
# lawxd : lawxd
# teknis : teknis
# aksinyaxd : aksinyaxd
# bagikan : bagi
# subcribe : subcribe
# kanal : kanal
# tvnya : tvnya
# sahabat : sahabat
# buruhxd : buruhxd
# sofyan : sofyan
# berlindung : lindung
# twkwkwkwk : twkwkwkwk
# andalan : andal
# padahal : padahal
# cacatxd : cacatxd
# adu : adu
# domba : domba
# ciri : ciri
# khas : khas
# merampungkan : rampung
# melumpuhkan : lumpuh
# mem : mem
# penganguran : penganguran
# kematian : mati
# meroket : roket
# every : every
# department : department
# register : register
# should : should
# sunset : sunset
# date : date
# so : so
# has : has
# reauthorized : reauthorized
# not : not
# bill : bill
# legislature : legislature
# bureaucrats : bureaucrats
# busy : busy
# all : all
# laws : laws
# also : also
# apply : apply
# congress : congress
# adakah : ada
# potensi : potensi
# hegemoni : hegemoni
# harakiri : harakiri
# suteki : suteki
# puspita : puspita
# satyawati : satyawati
# online : online
# uniol : uniol
# diponorogoxd : diponorogoxd
# hijrah : hijrah
# hahaha : hahaha
# ketok : ketok
# palu : palu
# lupakan : lupa
# dipidana : pidana
# pilih : pilih
# pakde : pakde
# stabilitas : stabilitas
# nasionalxd : nasionalxd
# lawannya : lawan
# memble : memble
# nyatanyalah : nyata
# memikirkan : pikir
# nasib : nasib
# betbuat : betbuat
# apaapa : apaapa
# sayangnya : sayang
# menerpa : terpa
# mengambil : ambil
# kesempatan : sempat
# menyusun : susun
# membahayakan : bahaya
# daze : daze
# independent : independent
# mlas : mlas
# held : held
# news : news
# conference : conference
# aug : aug
# criticize : criticize
# ucp : ucp
# for : for
# failing : failing
# proclaim : proclaim
# sections : sections
# labour : labour
# passed : passed
# once : once
# enactedthe : enactedthe
# new : new
# would : would
# force : force
# union : union
# members : members
# opt : opt
# donating : donating
# any : any
# dues : dues
# political : political
# causes : causes
# charity : charity
# fundraisers : fundraisers
# other : other
# functions : functions
# mengalahkan : kalah
# wuhanflu : wuhanflu
# diseasekillerxd : diseasekillerxd
# pelumat : lumat
# komorbi : komorbi
# komite : komite
# pbb : pbb
# meninjau : tinjau
# menangani : tangan
# adatxd : adatxd
# cerd : cerd
# membuktikan : bukti
# mengupayakan : upaya
# perlindungan : lindung
# menjamin : jamin
# tertawa : tertawa
# agustus : agustus
# tegaskan : tegas
# cacat : cacat
# mentimun : mentimun
# turun : turun
# meresponxd : meresponxd
# hubungan : hubung
# senyoryunyor : senyoryunyor
# campus : campus
# relasi : relasi
# tydak : tydak
# perloe : perloe
# eidzijnxd : eidzijnxd
# eidzijn : eidzijn
# sesuai : sesuai
# ta : ta
# akademisi : akademisi
# efha : efha
# uwiw : uwiw
# juncto : juncto
# disusupin : disusupin
# trauma : trauma
# misuh : misuh
# dikasih : kasih
# imbuhan : imbuh
# kontolxd : kontolxd
# ngetwit : ngetwit
# katain : katain
# kontol : kontol
# pure : pure
# venting : venting
# out : out
# diambil : ambil
# tautau : tautau
# diancem : diancem
# sjw : sjw
# moral : moral
# bersuara : suara
# ditenggelamkanxd : ditenggelamkanxd
# lumayan : lumayan
# diajak : ajak
# gangguan : ganggu
# pendengaran : dengar
# hattis : hattis
# rolef : rolef
# israels : israels
# economic : economic
# arrangements : arrangements
# similar : similar
# omnibudget : omnibudget
# countries : countries
# comparative : comparative
# multidisciplinary : multidisciplinary
# perspectives : perspectives
# on : on
# legislation : legislation
# ittai : ittai
# barsimantov : barsimantov
# edisi : edisi
# springer : springer
# nature : nature
# switzerland : switzerland
# ag : ag
# truthfully : truthfully
# few : few
# bills : bills
# are : are
# ever : ever
# anyone : anyone
# thats : thats
# appalling : appalling
# but : but
# how : how
# kami : kami
# system : system
# sadly : sadly
# wealth : wealth
# distribution : distribution
# dikenal juga sebagai : kenal juga bagai
# given : given
# what : what
# happened : happened
# since : since
# favor : favor
# changing : changing
# wont : wont
# agree : agree
# friend : friend
# wish : wish
# well : well
# cc : cc
# membangun : bangun
# dinasti : dinasti
# rumit : rumit
# pajak : pajak
# did : did
# gubernur : gubernur
# arkansas : arkansas
# asked : asked
# his : his
# redo : redo
# he : he
# realized : realized
# was : was
# error : error
# signxd : signxd
# mungkin : mungkin
# do : do
# too : too
# because : because
# one : one
# these : these
# photos : photos
# like : like
# others : others
# choc : choc
# tulisan : tulis
# penulis : tulis
# judul : judul
# kalimat : kalimat
# panrb : panrb
# komisi : komisi
# penyiaran : siar
# pencerahannya : cerah
# hendra : hendra
# kede : kede
# dirs : dirs
# aslinya : asli
# data : data
# sdng : sdng
# diup : diup
# abal : abal
# pengecoh : kecoh
# split : split
# hidden : hidden
# dllxd : dllxd
# dipelihara : pelihara
# penggemukan : gemuk
# kroni : kroni
# eve : eve
# january : january
# suggests : suggests
# passengers : passengers
# behave : behave
# when : when
# riding : riding
# paling : paling
# them : them
# could : could
# today : today
# kalikxd : kalikxd
# maaf : maaf
# lahir : lahir
# bathinxd : bathinxd
# menggentingyaitu : menggentingyaitu
# only : only
# paying : paying
# attention : attention
# dont : dont
# much : much
# theatre : theatre
# sneaking : sneaking
# verbiage : verbiage
# passages : passages
# nowxd : nowxd
# thing : thing
# gets : gets
# approved : approved
# better : better
# your : your
# shit : shit
# definition : definition
# smallholders : smallholders
# european : european
# commission : commission
# completely : completely
# arbitrary : arbitrary
# at : at
# odds : odds
# international : international
# mainstream : mainstream
# key : key
# developments : developments
# ranksb : ranksb
# ispo : ispo
# ensure : ensure
# path : path
# forward : forward
# tanda : tanda
# tangan : tangan
# mafia : mafia
# impor : impor
# howto : howto
# photoshop : photoshop
# house : house
# haunted : haunted
# mansion : mansion
# canadian : canadian
# librarians : librarians
# decry : decry
# captain : captain
# copyright : copyright
# scholars : scholars
# public : public
# interest : interest
# groups : groups
# oppose : oppose
# canadas : canadas
# internet : internet
# spying : spying
# witness : witness
# elections : elections
# says : says
# there : there
# provisions : provisions
# thatll : thatll
# disenfranchise : disenfranchise
# voters : voters
# wdisabilities : wdisabilities
# limits : limits
# types : types
# accommodation : accommodation
# kinds : kinds
# assistance : assistance
# allowed : allowed
# under : under
# mengunggah : unggah
# gambar : gambar
# ditempeli : tempel
# tulisantulisan : tulisantulisan
# nawacita : nawacita
# wajah : wajah
# sampingnya : samping
# notasi : notasi
# balok : balok
# logo : logo
# garuda : garuda
# pancasila : pancasila
# berwarna : warna
# hijau : hijau
# kemudahan : mudah
# berusaha : usaha
# dirusak : rusak
# kontroversial : kontroversial
# dipaksakan : paksa
# penurunan : turun
# lawan : lawan
# isu bohong : isu bohong
# berlakukah : laku
# prediksi : prediksi
# besaran : besar
# september : september
# oktober : oktober
# bertumbuhxd : bertumbuhxd
# kehadiran : hadir
# memangkas : mangkas
# menyederhanakan : sederhana
# daer : daer
# terkadang : terkadang
# tumpang : tumpang
# tindihsebenarnya : tindihsebenarnya
# bagus : bagus
# will : will
# eodbxd : eodbxd
# gemar : gemar
# menggoreng : goreng
# kadrun : kadrun
# memproduksi : produksi
# intoleran : intoleran
# merembet : rembet
# penolak : tolak
# tertuduh : tuduh
# pensiun : pensiun
# ndes : ndes
# jt : jt
# hilang : hilang
# karena : karena
# adek : adek
# isih : isih
# durung : durung
# kuliah : kuliah
# sijine : sijine
# wes : wes
# mlebu : mlebu
# kedokteran : dokter
# liquid : liquid
# pasan : pas
# iki : iki
# ningkat : ningkat
# omah : omah
# sedurunge : sedurunge
# bar : bar
# kapusan : kapusan
# bangun : bangun
# entek : entek
# cont : cont
# stafsus : stafsus
# milenial : milenial
# nyangkulxd : nyangkulxd
# nyataxd : nyataxd
# batalin : batalin
# aspek : aspek
# mempermudah : mudah
# keran : keran
# imporxd : imporxd
# bukti : bukti
# banyak bicara : banyak bicara
# jok : jok
# peringkat : peringkat
# berusahaxd : berusahaxd
# sebodoh : bodoh
# lumpuhnya : lumpuh
# meningkatnya : tingkat
# pungli : pungli
# menghilangkan : hilang
# suapxd : suapxd
# ok : ok
# perhitungan : hitung
# bunga : bunga
# sanksi : sanksi
# administrasi : administrasi
# dihitung : hitung
# terima : terima
# sticks : sticks
# interupsi : interupsi
# sadis : sadis
# mamasuki : mamasuki
# mendengarkan : dengar
# ahli : ahli
# keterangan : terang
# festival : festival
# film : film
# papuaxd : papuaxd
# senin : senin
# sekarangxd : sekarangxd
# topik : topik
# karpet : karpet
# koorporasi : koorporasi
# mengancam : ancam
# sda : sda
# passcode : passcode
# drama : drama
# manuver : manuver
# koalisi : koalisi
# komen : komen
# berguna : guna
# bertaring : taring
# dan kawan-kawan : dan kawan
# lancar : lancar
# jaya : jaya
# kiri : kiri
# cocok : cocok
# keluargamu : keluarga
# treveling : treveling
# jepang : jepang
# diobrakabr : diobrakabr
# voices : voices
# lewatkan : lewat
# populer : populer
# mbok : mbok
# beliau : beliau
# terdepan : depan
# mendukung : dukung
# da : da
# direktur : direktur
# pusako : pusako
# universitas : universitas
# andalas : andalas
# feri : feri
# amsari : amsari
# pemohon : mohon
# perkara : perkara
# puuxviii : puuxviii
# menjelas : jelas
# masiku : mas
# sederet : deret
# lainnyaga : lainnyaga
# artinyattp : artinyattp
# dicuekin : dicuekin
# mfs : mfs
# praising : praising
# article : article
# made : made
# about : about
# cluster : cluster
# ketenagakerjaanshould : ketenagakerjaanshould
# tell : tell
# even : even
# write : write
# obviously : obviously
# nolak : nolak
# plis : plis
# dieksploitasi : eksploitasi
# jalannya : jalan
# mulus : mulus
# pribumi : pribumi
# kuli : kuli
# tuan : tuan
# dorongan : dorong
# berharap : harap
# kurikulum : kurikulum
# anjuran : anjur
# ondernemer : ondernemer
# menyogok : sogok
# kolonial : kolonial
# pengawasan : awas
# buruhkuli : buruhkuli
# pintu : pintu
# terbuka : buka
# didenger : didenger
# dibilangnya : bilang
# ngelawan : ngelawan
# merusak : rusak
# nkri : nkri
# kebhinekaan : kebhinekaan
# mainin : mainin
# sara : sara
# kelihatan : lihat
# jahat : jahat
# alias : alias
# citra : citra
# bohong : bohong
# issued : issued
# regulation : regulation
# implementing : implementing
# introduced : introduced
# indiv : indiv
# gaungkan : gaung
# perjuangkan : juang
# menonton : tonton
# mengomentari : komentar
# menyebarluaskan : menyebarluaskan
# pkb : pkb
# puk : puk
# spamk : spamk
# yimm : yimm
# gelar : gelar
# fscm : fscm
# tanggapan : tanggap
# pc : pc
# jakartaxd : jakartaxd
# videnya : vide
# memperkokoh : kokoh
# argumentasi : argumentasi
# dibatalkan : batal
# junjunganmu : junjung
# parah : parah
# dikit : dikit
# baliho : baliho
# informatif : informatif
# lengkap : lengkap
# off : off
# respek : respek
# anti : anti
# sush : sush
# iya : iya
# antiomnibus : antiomnibus
# protests : protests
# year : year
# protesters : protesters
# pee : pee
# us : us
# embassy : embassy
# grounds : grounds
# see : see
# hoaks : hoaks
# mk : mk
# mengeluarkan : keluar
# internal : internal
# bersifat : sifat
# kontranarasi : kontranarasi
# menghidupkan : hidup
# penghinaan : hina
# publikxd : publikxd
# kasian : kasi
# ditunggangi : tunggang
# oknum : oknum
# cellebrite : cellebrite
# ufed : ufed
# touch : touch
# pemberlakuan : laku
# penghidupan : hidup
# menderita : derita
# cilakaxd : cilakaxd
# dasar : dasar
# perseteruan : seteru
# model : model
# berlanjutxd : berlanjutxd
# logikanya : logika
# biangnya : biang
# kegaduhan : gaduh
# titik : titik
# temuxd : temuxd
# gelombang : gelombang
# membludak : membludak
# joko : joko
# widodo : widodo
# mencabut : cabut
# inixd : inixd
# draf : draf
# membingunngkan : membingunngkan
# naskah : naskah
# disusun : susun
# mekanisme : mekanisme
# diperolehxd : diperolehxd
# gaduh : gaduh
# ditambah : tambah
# turunannyaxd : turunannyaxd
# trend : trend
# otoritarian : otoritarian
# nampak : nampak
# memaksa : paksa
# reses : reses
# kepenanganan : tangan
# covidxd : covidxd
# kuhp : kuhp
# beleid : beleid
# digarap : garap
# banjir : banjir
# kritikanxd : kritikanxd
# tragisuu : tragisuu
# lawapakah : lawapakah
# tandanya : tanda
# peta : peta
# konsep : konsep
# perundangundangan : perundangundangan
# lintas : lintas
# sektoral : sektoral
# ketentuan : tentu
# sektorsektor : sektorsektor
# efektif : efektif
# mengatasi : atas
# izinxd : izinxd
# berencana : rencana
# membatalkan : batal
# perundangundanganxd : perundangundanganxd
# bergegas : gegas
# merampingkan : ramping
# kerjaxd : kerjaxd
# mjd : mjd
# sederhana : sederhana
# rakyatxd : rakyatxd
# suka : suka
# lagunya : lagu
# soundtrack : soundtrack
# tiktok : tiktok
# mau tahu urusan orang : mau tahu urus orang
# asik : asik
# lucu : lucu
# nyemplung : nyemplung
# fandom : fandom
# omongan : omong
# berlakunya : laku
# ketahanan : tahan
# pangan : pangan
# diandalkan : andal
# produks : produks
# terbitnya : terbit
# penggusuran : gusur
# pengaturan : atur
# pertanahan : tanah
# perkebunan : kebun
# kehutanan : hutan
# utama : utama
# pengadaan : ada
# rasav : rasav
# eling : eling
# sluurr : sluurr
# cah : cah
# enom : enom
# mengko : mengko
# nek : nek
# gelem : gelem
# dho : dho
# dadekno : dadekno
# arep : arep
# apakne : apakne
# cumaxd : cumaxd
# mentri : tri
# web : web
# mental : mental
# mutunya : mutu
# budgetnya : budgetnya
# manxd : manxd
# bisanya : bisa
# cm : cm
# diinterupsixd : diinterupsixd
# dibawah : bawah
# pengalihan : alih
# waktu : waktu
# bergaung : gaung
# bukanxd : bukanxd
# tlah : tlah
# dc : dc
# vision : vision
# zero : zero
# required : required
# streets : streets
# designated : designated
# having : having
# protected : protected
# bike : bike
# lanes : lanes
# bus : bus
# or : or
# car : car
# free : free
# reconstructed : reconstructed
# used : used
# cambridge : cambridge
# ordinance : ordinance
# mengerti : erti
# kadroen : kadroen
# begaya : begaya
# ngucap : ngucap
# ampun : ampun
# droen : droen
# gebok : gebok
# polisixd : polisixd
# membantah : ban
# mahfudxd : mahfudxd
# orangnya : orang
# muisxd : muisxd
# mendengar : dengar
# nasi : nasi
# pasir : pasir
# gesit : gesit
# indonesiaxd : indonesiaxd
# kpkxd : kpkxd
# permenkes : permenkes
# vaksinasixd : vaksinasixd
# stat : stat
# purwono : purwono
# dana : dana
# psbbppkm : psbbppkm
# tarif : tarif
# pancasi : pancasi
# laptop : laptop
# zirex : zirex
# karup : karup
# terima kasih : terima kasih
# pantau : pantau
# insya : insya
# allah : allah
# group : group
# akal : akal
# sehat : sehat
# bahu : bahu
# membahu : bahu
# perhatian : perhati
# type : type
# menyembunyikan : sembunyi
# keterbukaan : buka
# tentang : tentang
# personal : personal
# jelekxd : jelekxd
# pimpinan : pimpin
# pastixd : pastixd
# tandai : tanda
# orgnya : orgnya
# dki : dki
# mohon : mohon
# doa : doa
# supportnya : supportnya
# kawan : kawan
# berjuang : juang
# perundingan : runding
# tongkosong : tongkosong
# hahahaha : hahahaha
# psbb : psbb
# diadakan : ada
# perguruan : guru
# instansi : instansi
# penghasil : hasil
# pintar : pintar
# dibandingkan : banding
# basis : basis
# intelektual : intelektual
# agen : agen
# batas : batas
# november : november
# disimak : simak
# terhormat : hormat
# mencari : cari
# konten : konten
# kartunanshitpostinformatif : kartunanshitpostinformatif
# nanti : nanti
# repost : repost
# pesbuk : pesbuk
# beken : beken
# pesbukxd : pesbukxd
# bosen : bosen
# main : main
# ya sudah : ya sudah
# aktifnya : aktif
# twatterxd : twatterxd
# anon : anon
# pengamat : amat
# perpolitikan : politik
# twatter : twatter
# posting : posting
# toktik : toktik
# simpanan : simpan
# lps : lps
# swasta : swasta
# mencoba : coba
# menjegal : jegal
# disepakati : pakat
# haigh : haigh
# tad : tad
# janus : janus
# faced : faced
# hand : hand
# commoners : commoners
# clapham : clapham
# seen : seen
# arbitrators : arbitrators
# guilt : guilt
# yet : yet
# trusted : trusted
# think : think
# ourselves : ourselves
# terbaik : baik
# aktor : aktor
# global : global
# parameter : parameter
# faktanya : fakta
# daya : daya
# habis : habis
# dicaplok : caplok
# banyak : banyak
# pertambangan : tambang
# merampas : rampas
# net : net
# mp : mp
# hc : hc
# adp : adp
# quash : quash
# against : against
# brotherinlaw : brotherinlaw
# vague : vague
# allegations : allegations
# konsekuensi : konsekuensi
# pengembangan : kembang
# percetakan : cetak
# balihoxd : balihoxd
# sblmnya : sblmnya
# pengangguran : anggur
# dicatut : catut
# kartu : kartu
# prakerja : prakerja
# tambang : tambang
# proy : proy
# buzzer : buzzer
# trsebut : trsebut
# andil : andil
# menggeser : geser
# urgensi : urgensi
# posisi : posisi
# mercusuar : mercusuar
# peradaban : adab
# mnjadi : mnjadi
# pion : pion
# pasar : pasar
# mr : mr
# disetel : setel
# januari : januari
# sok : sok
# pura : pura
# demokratis : demokratis
# kayaknya : kayak
# bumn : bumn
# ironi : ironi
# zaman : zaman
# permanen : permanen
# hubungannya : hubung
# yaxd : yaxd
# generasi : generasi
# muda : muda
# tertarik : tarik
# penegakan : tega
# kepempimpinan : kepempimpinan
# paduka : paduka
# jang : jang
# mulia : mulia
# diberantas : berantas
# wabah : wabah
# asean : asean
# tunjukkan : tunjuk
# njir : njir
# ditandatangani : ditandatangani
# ngelakuin : ngelakuin
# aktivisme : aktivisme
# ituu : ituu
# fans : fans
# kpop : kpop
# valentino : valentino
# rossi : rossi
# ngadain : ngadain
# vaksinasi : vaksinasi
# kpopers : kpopers
# infrastruktur : infrastruktur
# telekomunikasi : telekomunikasi
# broadband : broadband
# melengkapi : lengkap
# regulasi : regulasi
# primer : primer
# lha : lha
# kelakuan : laku
# dihormatin : dihormatin
# microphone : microphone
# kuatkan : kuat
# imun : imun
# gerakan : gera
# peduli : peduli
# tetanggasepiring : tetanggasepiring
# berlebih : lebih
# diharapkan : harap
# sanaada : sanaada
# diblow : diblow
# please : please
# edukasi : edukasi
# menghiraukan : hirau
# akibat : akibat
# gizi : gizi
# terbeli : beli
# berbekal : bekal
# consolidate : consolidate
# this : this
# where : where
# harmful : harmful
# stuff : stuff
# makers : makers
# properly : properly
# account : account
# unless : unless
# citizens : citizens
# voting : voting
# small : small
# transpar : transpar
# omron : omron
# beras : beras
# tidak mau : tidak mau
# persilakan : sila
# mkxd : mkxd
# pengin : pengin
# lengserkan : lengser
# masalahxd : masalahxd
# nyenyak : nyenyak
# merambat : rambat
# laju : laju
# senyap : senyap
# bbrp : bbrp
# influencer : influencer
# masmas : masmas
# dicengcengin : dicengcengin
# ramerame : ramerame
# dukungan : dukung
# bodongxd : bodongxd
# ipo : ipo
# bukalapak : bukalapak
# profitabilitasnya : profitabilitas
# bodong : bodong
# jngan : jngan
# tt : tt
# pjk : pjk
# kendaraan : kendara
# dtnya : dtnya
# yntkts : yntkts
# jawabannya : jawab
# dsruh : dsruh
# tnya : tnya
# polisi : polisi
# kan : kan
# ngehek : ngehek
# ily : ily
# dijadiin : dijadiin
# mendalami : dalam
# treasure : treasure
# besarxd : besarxd
# manja : manja
# encik : encik
# malaysia : malaysia
# bising : bising
# lepas : lepas
# thailand : thailand
# month : month
# perdana : perdana
# letak : letak
# jawatan : jawat
# imo : imo
# malaysians : malaysians
# penyabar : sabar
# panen : panen
# produksi : produksi
# ngimpi : ngimpi
# pingin : pingin
# berminat : minat
# harto : harto
# dikriminalisasi : kriminalisasi
# pembenihan : benih
# gov : gov
# kemps : kemps
# signature : signature
# georgia : georgia
# lawmakers : lawmakers
# overthrowing : overthrowing
# election : election
# results : results
# likeeasy : likeeasy
# legal : legal
# if : if
# had : had
# land : land
# wed : wed
# djt : djt
# nd : nd
# term : term
# senators : senators
# purdue : purdue
# loefflerall : loefflerall
# illegitimate : illegitimate
# diobrakabrik : diobrakabrik
# satpol : satpol
# spesies : spesies
# bersedih : sedih
# cetuskan : cetus
# teken : teken
# membantu : bantu
# meligitimasi : meligitimasi
# memperkuat : kuat
# mengkonsolidasi : konsolidasi
# memperkaya : kaya
# kemakmur : makmur
# dorna : dorna
# motogp : motogp
# merekrut : rekrut
# pembalap : balap
# pwkt : pwkt
# check : check
# piece : piece
# trafalgar : trafalgar
# worst : worst
# generation : generation
# ichiban : ichiban
# kuji : kuji
# best : best
# maria : maria
# menang : menang
# gunawan : gunawan
# metode : metode
# hukumnya : hukum
# mengulas : ulas
# konstitusionalitas : konstitusionalitas
# filosofi : filosofi
# membentuk : bentuk
# moralitas : moralitas
# hakim : hakim
# menyerahkan : serah
# perbaikan : baik
# berdasarkan : dasar
# inza : inza
# perundang : undang
# undanganxd : undanganxd
# saksi : saksi
# salam : salam
# mengukur : ukur
# pelanggaran : langgar
# praktik : praktik
# inzage : inzage
# tim : tim
# kuasa : kuasa
# advokasi : advokasi
# kepal : kepal
# pembela : bela
# tertulis : tulis
# pancasilais : pancasilais
# prestasixd : prestasixd
# lahirlah : lahir
# dimatiinxd : dimatiinxd
# kebayang : bayang
# asal bunyi : asal bunyi
# bayangin : bayangin
# beserta : serta
# rusuh : rusuh
# tembakan : tembak
# dipadukan : padu
# cerdas : cerdas
# rima : rima
# hardcorepunk : hardcorepunk
# album : album
# pemulihan : pulih
# ekonomi : ekonomi
# pasca : pasca
# didukung : dukung
# struktural : struktural
# implementasi : implementasi
# perpajakan : paja
# kup : kup
# mentransformasikan : transformasi
# tanganipandemi : tanganipandemi
# respresifitas : respresifitas
# utamanya : utama
# kerap : kerap
# pelajar : ajar
# kemakmuran : makmur
# mother : mother
# em : em
# shot : shot
# getting : getting
# jesal : jesal
# kekayaanindonesia : kekayaanindonesia
# dilindungi : lindung
# waspada : waspada
# menghisap : menghisap
# kekayaan : kaya
# kerasa : rasa
# euy : euy
# lanjutan : lanjut
# tata : tata
# pedih : pedih
# commodity : commodity
# aduhai : aduhai
# nilainya : nilai
# terdampaknya : dampak
# bonus : bonus
# ilangg : ilangg
# taeeeee : taeeeee
# pdipe : pdipe
# cpet : cpet
# bgnianxd : bgnianxd
# cilik : cilik
# electoral : electoral
# politics : politics
# constituitonal : constituitonal
# company : company
# migration : migration
# banning : banning
# erosion : erosion
# passing : passing
# maritime : maritime
# archeology : archeology
# cinema : cema
# tms : tms
# appropriations : appropriations
# called : called
# save : save
# americas : americas
# pastime : pastime
# inserted : inserted
# mlb : mlb
# owners : owners
# pay : pay
# overtime : overtime
# day : day
# overriding : overriding
# pusing : pusing
# keketuaan : ketua
# sambut : sambut
# obra : obra
# enacted : enacted
# rd : rd
# united : united
# states : states
# signed : signed
# president : president
# clinton : clinton
# outlines : outlines
# school : school
# code : code
# changes : changes
# recent : recent
# worth : worth
# noting : noting
# topics : topics
# substitute : substitute
# teachers : teachers
# construction : construction
# facilities : facilities
# eitc : eitc
# fiscal : fiscal
# amendment : amendment
# reform : reform
# agricultural : agricultural
# activity : activity
# protection : protection
# http : http
# smi : smi
# kembalikan : kembali
# aset : aset
# vehicle : vehicle
# drawn : drawn
# propelled : propelled
# animal : animal
# power : power
# conveyance : conveyance
# goods : goods
# parcels : parcels
# hire : hire
# railway : railway
# tramway : tramway
# includes : includes
# motor : motor
# bicycle : bicycle
# ...
# tentang : tentang
# personal : personal
# jelekxd : jelekxd
# pimpinan : pimpin
# pastixd : pastixd
# tandai : tanda
# orgnya : orgnya
# dki : dki
# mohon : mohon
# doa : doa
# supportnya : supportnya
# kawan : kawan
# berjuang : juang
# perundingan : runding
# tongkosong : tongkosong
# hahahaha : hahahaha
# psbb : psbb
# diadakan : ada
# perguruan : guru
# instansi : instansi
# penghasil : hasil
# pintar : pintar
# dibandingkan : banding
# basis : basis
# intelektual : intelektual
# agen : agen
# batas : batas
# november : november
# disimak : simak
# terhormat : hormat
# mencari : cari
# konten : konten
# kartunanshitpostinformatif : kartunanshitpostinformatif
# nanti : nanti
# repost : repost
# pesbuk : pesbuk
# beken : beken
# pesbukxd : pesbukxd
# bosen : bosen
# main : main
# ya sudah : ya sudah
# aktifnya : aktif
# twatterxd : twatterxd
# anon : anon
# pengamat : amat
# perpolitikan : politik
# twatter : twatter
# posting : posting
# toktik : toktik
# simpanan : simpan
# lps : lps
# swasta : swasta
# mencoba : coba
# menjegal : jegal
# disepakati : pakat
# haigh : haigh
# tad : tad
# janus : janus
# faced : faced
# hand : hand
# commoners : commoners
# clapham : clapham
# seen : seen
# arbitrators : arbitrators
# guilt : guilt
# yet : yet
# trusted : trusted
# think : think
# ourselves : ourselves
# terbaik : baik
# aktor : aktor
# global : global
# parameter : parameter
# faktanya : fakta
# daya : daya
# habis : habis
# dicaplok : caplok
# banyak : banyak
# pertambangan : tambang
# merampas : rampas
# net : net
# mp : mp
# hc : hc
# adp : adp
# quash : quash
# against : against
# brotherinlaw : brotherinlaw
# vague : vague
# allegations : allegations
# konsekuensi : konsekuensi
# pengembangan : kembang
# percetakan : cetak
# balihoxd : balihoxd
# sblmnya : sblmnya
# pengangguran : anggur
# dicatut : catut
# kartu : kartu
# prakerja : prakerja
# tambang : tambang
# proy : proy
# buzzer : buzzer
# trsebut : trsebut
# andil : andil
# menggeser : geser
# urgensi : urgensi
# posisi : posisi
# mercusuar : mercusuar
# peradaban : adab
# mnjadi : mnjadi
# pion : pion
# pasar : pasar
# mr : mr
# disetel : setel
# januari : januari
# sok : sok
# pura : pura
# demokratis : demokratis
# kayaknya : kayak
# bumn : bumn
# ironi : ironi
# zaman : zaman
# permanen : permanen
# hubungannya : hubung
# yaxd : yaxd
# generasi : generasi
# muda : muda
# tertarik : tarik
# penegakan : tega
# kepempimpinan : kepempimpinan
# paduka : paduka
# jang : jang
# mulia : mulia
# diberantas : berantas
# wabah : wabah
# asean : asean
# tunjukkan : tunjuk
# njir : njir
# ditandatangani : ditandatangani
# ngelakuin : ngelakuin
# aktivisme : aktivisme
# ituu : ituu
# fans : fans
# kpop : kpop
# valentino : valentino
# rossi : rossi
# ngadain : ngadain
# vaksinasi : vaksinasi
# kpopers : kpopers
# infrastruktur : infrastruktur
# telekomunikasi : telekomunikasi
# broadband : broadband
# melengkapi : lengkap
# regulasi : regulasi
# primer : primer
# lha : lha
# kelakuan : laku
# dihormatin : dihormatin
# microphone : microphone
# kuatkan : kuat
# imun : imun
# gerakan : gera
# peduli : peduli
# tetanggasepiring : tetanggasepiring
# berlebih : lebih
# diharapkan : harap
# sanaada : sanaada
# diblow : diblow
# please : please
# edukasi : edukasi
# menghiraukan : hirau
# akibat : akibat
# gizi : gizi
# terbeli : beli
# berbekal : bekal
# consolidate : consolidate
# this : this
# where : where
# harmful : harmful
# stuff : stuff
# makers : makers
# properly : properly
# account : account
# unless : unless
# citizens : citizens
# voting : voting
# small : small
# transpar : transpar
# omron : omron
# beras : beras
# tidak mau : tidak mau
# persilakan : sila
# mkxd : mkxd
# pengin : pengin
# lengserkan : lengser
# masalahxd : masalahxd
# nyenyak : nyenyak
# merambat : rambat
# laju : laju
# senyap : senyap
# bbrp : bbrp
# influencer : influencer
# masmas : masmas
# dicengcengin : dicengcengin
# ramerame : ramerame
# dukungan : dukung
# bodongxd : bodongxd
# ipo : ipo
# bukalapak : bukalapak
# profitabilitasnya : profitabilitas
# bodong : bodong
# jngan : jngan
# tt : tt
# pjk : pjk
# kendaraan : kendara
# dtnya : dtnya
# yntkts : yntkts
# jawabannya : jawab
# dsruh : dsruh
# tnya : tnya
# polisi : polisi
# kan : kan
# ngehek : ngehek
# ily : ily
# dijadiin : dijadiin
# mendalami : dalam
# treasure : treasure
# besarxd : besarxd
# manja : manja
# encik : encik
# malaysia : malaysia
# bising : bising
# lepas : lepas
# thailand : thailand
# month : month
# perdana : perdana
# letak : letak
# jawatan : jawat
# imo : imo
# malaysians : malaysians
# penyabar : sabar
# panen : panen
# produksi : produksi
# ngimpi : ngimpi
# pingin : pingin
# berminat : minat
# harto : harto
# dikriminalisasi : kriminalisasi
# pembenihan : benih
# gov : gov
# kemps : kemps
# signature : signature
# georgia : georgia
# lawmakers : lawmakers
# overthrowing : overthrowing
# election : election
# results : results
# likeeasy : likeeasy
# legal : legal
# if : if
# had : had
# land : land
# wed : wed
# djt : djt
# nd : nd
# term : term
# senators : senators
# purdue : purdue
# loefflerall : loefflerall
# illegitimate : illegitimate
# diobrakabrik : diobrakabrik
# satpol : satpol
# spesies : spesies
# bersedih : sedih
# cetuskan : cetus
# teken : teken
# membantu : bantu
# meligitimasi : meligitimasi
# memperkuat : kuat
# mengkonsolidasi : konsolidasi
# memperkaya : kaya
# kemakmur : makmur
# dorna : dorna
# motogp : motogp
# merekrut : rekrut
# pembalap : balap
# pwkt : pwkt
# check : check
# piece : piece
# trafalgar : trafalgar
# worst : worst
# generation : generation
# ichiban : ichiban
# kuji : kuji
# best : best
# maria : maria
# menang : menang
# gunawan : gunawan
# metode : metode
# hukumnya : hukum
# mengulas : ulas
# konstitusionalitas : konstitusionalitas
# filosofi : filosofi
# membentuk : bentuk
# moralitas : moralitas
# hakim : hakim
# menyerahkan : serah
# perbaikan : baik
# berdasarkan : dasar
# inza : inza
# perundang : undang
# undanganxd : undanganxd
# saksi : saksi
# salam : salam
# mengukur : ukur
# pelanggaran : langgar
# praktik : praktik
# inzage : inzage
# tim : tim
# kuasa : kuasa
# advokasi : advokasi
# kepal : kepal
# pembela : bela
# tertulis : tulis
# pancasilais : pancasilais
# prestasixd : prestasixd
# lahirlah : lahir
# dimatiinxd : dimatiinxd
# kebayang : bayang
# asal bunyi : asal bunyi
# bayangin : bayangin
# beserta : serta
# rusuh : rusuh
# tembakan : tembak
# dipadukan : padu
# cerdas : cerdas
# rima : rima
# hardcorepunk : hardcorepunk
# album : album
# pemulihan : pulih
# ekonomi : ekonomi
# pasca : pasca
# didukung : dukung
# struktural : struktural
# implementasi : implementasi
# perpajakan : paja
# kup : kup
# mentransformasikan : transformasi
# tanganipandemi : tanganipandemi
# respresifitas : respresifitas
# utamanya : utama
# kerap : kerap
# pelajar : ajar
# kemakmuran : makmur
# mother : mother
# em : em
# shot : shot
# getting : getting
# jesal : jesal
# kekayaanindonesia : kekayaanindonesia
# dilindungi : lindung
# waspada : waspada
# menghisap : menghisap
# kekayaan : kaya
# kerasa : rasa
# euy : euy
# lanjutan : lanjut
# tata : tata
# pedih : pedih
# commodity : commodity
# aduhai : aduhai
# nilainya : nilai
# terdampaknya : dampak
# bonus : bonus
# ilangg : ilangg
# taeeeee : taeeeee
# pdipe : pdipe
# cpet : cpet
# bgnianxd : bgnianxd
# cilik : cilik
# electoral : electoral
# politics : politics
# constituitonal : constituitonal
# company : company
# migration : migration
# banning : banning
# erosion : erosion
# passing : passing
# maritime : maritime
# archeology : archeology
# cinema : cema
# tms : tms
# appropriations : appropriations
# called : called
# save : save
# americas : americas
# pastime : pastime
# inserted : inserted
# mlb : mlb
# owners : owners
# pay : pay
# overtime : overtime
# day : day
# overriding : overriding
# pusing : pusing
# keketuaan : ketua
# sambut : sambut
# obra : obra
# enacted : enacted
# rd : rd
# united : united
# states : states
# signed : signed
# president : president
# clinton : clinton
# outlines : outlines
# school : school
# code : code
# changes : changes
# recent : recent
# worth : worth
# noting : noting
# topics : topics
# substitute : substitute
# teachers : teachers
# construction : construction
# facilities : facilities
# eitc : eitc
# fiscal : fiscal
# amendment : amendment
# reform : reform
# agricultural : agricultural
# activity : activity
# protection : protection
# http : http
# smi : smi
# kembalikan : kembali
# aset : aset
# vehicle : vehicle
# drawn : drawn
# propelled : propelled
# animal : animal
# power : power
# conveyance : conveyance
# goods : goods
# parcels : parcels
# hire : hire
# railway : railway
# tramway : tramway
# includes : includes
# motor : motor
# bicycle : bicycle
# blacklist : blacklist
# azis : azis
# disebutsebut : disebutsebut
# suap : suap
# clipboard : clipboard
# masi : mas
# stuck : stuck
# pelda : pelda
# hestek : hestek
# alma : alma
# jogja : jogja
# keturunan : turun
# non : non
# pribumixd : pribumixd
# aliaa : aliaa
# pri : pri
# pnya : pnya
# mmg : mmg
# keterkaitan : kait
# quo : quo
# tunda : tunda
# ngepes : ngepes
# kosnya : kosnya
# yudos : yudos
# koruptorxd : koruptorxd
# konstitusixd : konstitusixd
# istilahoutsourcing : istilahoutsourcing
# diperbincangkan : bincang
# jobseeker : jobseeker
# laluxd : laluxd
# sani : sani
# ramdanixd : ramdanixd
# bongkar : bongkar
# prosedural : prosedural
# dikonversi : konversi
# dikompensasikan : kompensasi
# bentuk : bentuk
# mengkompensasi : kompensasi
# menjaga : jaga
# kelestarian : lestari
# dibeli : beli
# rancangan : rancang
# proses : proses
# perundangannya : undang
# anggaran : anggar
# trilyun : trilyun
# masak : masak
# beli : beli
# vaksinxd : vaksinxd
# rawan : rawan
# korupsixd : korupsixd
# diperiksa : periksa
# tameng : tameng
# bhw : bhw
# dipi : dipi
# kesehatan : sehat
# minister : mister
# water : water
# security : security
# eva : eva
# lawler : lawler
# confirms : confirms
# two : two
# environmental : environmental
# delayed : delayed
# until : until
# lanjut : lanjut
# due : due
# opposition : opposition
# terc : terc
# amendments : amendments
# debated : debated
# august : august
# sittings : sittings
# dikiranya : kira
# enteng : enteng
# sosmed : sosmed
# benerbener : benerbener
# nganalisis : nganalisis
# isi : isi
# least : least
# berapa : berapa
# bnyak : bnyak
# asa : asa
# rusli : rusli
# saudara : saudara
# kelesuan : lesu
# bernaung : naung
# terbesar : besar
# dibidangnya : bidang
# bangkit : bangkit
# seat : seat
# corruption : corruption
# included : included
# language : language
# nothing : nothing
# winfrastructure : winfrastructure
# crush : crush
# crypto : crypto
# industry : industry
# dramatically : dramatically
# expand : expand
# govt : govt
# surveillance : surveillance
# over : over
# entire : entire
# ecosystem : ecosystem
# resistance : resistance
# isnt : isnt
# exactly : exactly
# hca : hca
# appears : appears
# issue : issue
# appeared : appeared
# previous : previous
# courts : courts
# were : were
# erroneous : erroneous
# application : application
# judges : judges
# ruling : ruling
# labelled : labelled
# deliberately : deliberately
# ignori : ignori
# chmura : chmura
# doesnt : doesnt
# privacy : privacy
# eu : eu
# does : does
# likely : likely
# lawful : lawful
# ask : ask
# vaccination : vaccination
# measure : measure
# known : known
# man : man
# ie : ie
# average : average
# person : person
# establi : establi
# bangsap : bangsap
# memangxd : memangxd
# omzet : omzet
# pedagang : dagang
# ancoooorrrrxd : ancoooorrrrxd
# rando : rando
# gop : gop
# laundry : laundry
# list : list
# ready : ready
# cram : cram
# charge : charge
# border : border
# speech : speech
# voter : voter
# orderxd : orderxd
# advance : advance
# offers : offers
# opp : opp
# leftist : leftist
# what the fuck : what the fuck
# pap : pap
# plakat : plakat
# urusanmu : urus
# cewek : cewek
# pacaran : pacar
# gila : gila
# cowoknya : cowok
# nyuruh : nyuruh
# sholat : sholat
# amdal : amdal
# dilanggar : langgar
# diapus : diapus
# ah : ah
# goblokkkk : goblokkkk
# massie : massie
# clear : clear
# context : context
# sabar : sabar
# conspired : conspired
# stick : stick
# specific : specific
# intent : intent
# letting : letting
# county : county
# council : council
# override : override
# sam : sam
# pages : pages
# health : health
# pantesan : pantesan
# menghindari : hindar
# dilema : dilema
# penciptaan : cipta
# {'floran': 'floran', 'latihan': 'latih', 'menghapus': 'hapus', 'omnibus': 'omnibus', 'law': 'law', 'memblokir': 'blokir', 'netizen': 'netizen', 'wkwkwkkk': 'wkwkwkkk', 'nawww': 'nawww', 'she': 'she', 'literally': 'literally', 'said': 'said', 'sedang apa': 'sedang apa', 'demo': 'demo', 'susah': 'susah', 'orang': 'orang', 'kerja': 'kerja', 'during': 'during', 'protest': 'protest', 'cant': 'cant', 'read': 'read', 'the': 'the', 'fuckkng': 'fuckkng', 'room': 'room', 'tidak ada uang': 'tidak ada uang', 'ppkm': 'ppkm', 'minggu': 'minggu', 'mempersingkat': 'singkat', 'undangundang': 'undangundang', 'lakok': 'lakok', 'kesini': 'kesini', 'kabeh': 'kabeh', 'undangi': 'undang', 'entok': 'entok', 'berkat': 'berkat', 'ogak': 'ogak', 'kui': 'kui', 'ngko': 'ngko', 'perpanjang': 'panjang', 'karyawan': 'karyawan', 'wajib': 'wajib', 'strp': 'strp', 'kantor': 'kantor', 'pusat': 'pusat', 'perbelanjaan': 'belanja', 'tutup': 'tutup', 'rakyat': 'rakyat', 'ganti': 'ganti', 'wna': 'wna', 'koyo': 'koyo', 'lawapa': 'lawapa', 'artine': 'artine', 'onok': 'onok', 'sing': 'sing', 'weruhyo': 'weruhyo', 'mek': 'mek', 'ngrusaki': 'ngrusaki', 'taman': 'taman', 'ikuw': 'ikuw', 'mrk': 'mrk', 'masukkan': 'masuk', 'uu': 'uu', 'sapujagad': 'sapujagad', 'diganggu': 'ganggu', 'gugat': 'gugat', 'cegah': 'cegah', 'korupsi': 'korupsi', 'birokrasi': 'birokrasi', 'didu': 'didu', 'bagaimana': 'bagaimana', 'sri': 'sri', 'mulyani': 'mulyani', 'csbikin': 'csbikin', 'grafik': 'grafik', 'melandai': 'landai', 'menjadikan': 'jadi', 'vaksin': 'vaksin', 'dijual': 'jual', 'bubarkan': 'bubar', 'fpi': 'fpi', 'penjarakan': 'penjara', 'ibhrs': 'ibhrs', 'bunuh': 'bunuh', 'remaja': 'remaja', 'pengawal': 'awal', 'rombongan': 'rombong', 'habib': 'habib', 'nambah': 'nambah', 'hutang': 'hutang', 'dirancang': 'rancang', 'dikeluarkannya': 'keluar', 'keputusan': 'putus', 'perppu': 'perppu', 'nomor': 'nomor', 'th': 'th', 'corona': 'corona', 'dimana': 'mana', 'perpres': 'pres', 'kedudukannya': 'duduk', 'diatas': 'atas', 'ngaco': 'ngaco', 'negeri': 'negeri', 'halah': 'halah', 'ngantor': 'ngantor', 'kerjanya': 'kerja', 'buktinya': 'bukti', 'aspirasi': 'aspirasi', 'diperjuangkan': 'juang', 'dpr': 'dpr', 'ite': 'ite', 'kpk': 'kpk', 'uud': 'uud', 'tho': 'tho', 'anggota': 'anggota', 'bobo': 'bobo', 'manis': 'manis', 'deh': 'deh', 'rumah': 'rumah', 'gedu': 'gedu', 'bahas': 'bahas', 'ruu': 'ruu', 'pks': 'pks', 'diskusi': 'diskusi', 'belajar': 'ajar', 'sejarah': 'sejarah', 'terbentuknya': 'bentuk', 'britania': 'britania', 'raya': 'raya', 'agama': 'agama', 'politik': 'politik', 'negara': 'negara', 'indonesia': 'indonesia', 'jr': 'jr', 'pasal': 'pasal', 'mas': 'mas', 'diultra': 'ultra', 'petita': 'petita', 'pry': 'pry', 'bantu': 'bantu', 'kasih': 'kasih', 'konteks': 'konteks', 'salah': 'salah', 'promotor': 'promotor', 'cipta': 'cipta', 'kadin': 'kadin', 'keberpiha': 'keberpiha', 'terpenting': 'penting', 'mengkritik': 'kritik', 'konsistensi': 'konsistensi', 'integritas': 'integritas', 'oposisi': 'oposisi', 'bertemu': 'temu', 'mahasiswa': 'mahasiswa', 'kritikus': 'kritikus', 'pemerintah': 'perintah', 'mengesahkan': 'kesah', 'azhar': 'azhar', 'dejavu': 'dejavu', 'seperti': 'seperti', 'begitu': 'begitu', 'ngomong-ngomong': 'ngomong-ngomong', 'bgm': 'bgm', 'iwan': 'iwan', 'sumule': 'sumule', 'uji': 'uji', 'materi': 'materi', 'turunannya': 'turun', 'gilak': 'gilak', 'dari': 'dari', 'burden': 'burden', 'sharing': 'sharing', 'diperkuat': 'kuat', 'konstitusional': 'konstitusional', 'majelis': 'majelis', 'papua': 'papua', 'barat': 'barat', 'lembaga': 'lembaga', 'representatif': 'representatif', 'resmi': 'resmi', 'tolak': 'tolak', 'pembahasan': 'bahas', 'otsus': 'otsus', 'jalan': 'jalan', 'kebut': 'kebut', 'ri': 'ri', 'pemerinth': 'pemerinth', 'last': 'last', 'tweet': 'tweet', 'bicara': 'bicara', 'protes': 'protes', 'dukung': 'dukung', 'cia': 'cia', 'kingkin': 'kingkin', 'anida': 'anida', 'bebas': 'bebas', 'penjara': 'penjara', 'terkait': 'kait', 'menyiarkan': 'siar', 'kabar': 'kabar', 'tol': 'tol', 'people': 'people', ' ...
# ------------------------
# Pandas Apply:   0%|          | 0/505 [00:00<?, ?it/s]
# 0      [floran, latih, hapus, omnibus, law, blokir, n...
# 1      [nawww, she, literally, said, sedang apa, demo...
# 2      [omnibus, law, demo, tidak ada uang, demo, ppk...
# 3      [omnibus, law, singkat, undangundang, lakok, k...
# 4      [koyo, demo, omnibus, lawapa, artine, onok, si...
#                              ...
# 500    [massie, and, to, be, clear, the, context, is,...
# 501    [pantesan, pingin, banget, omnibus, law, tuju,...
# 502    [ekonomi, politik, omnibus, law, dilema, inves...
# 503                       [me, efek, omnibus, law, mana]
# 504                       [me, efek, omnibus, law, mana]
# Name: tweet_tokens_stemmed, Length: 505, dtype: object

# %%
TWEET_DATA.to_excel("PreP.xlsx")

# %%
TWEET_DATA.head()
# Out:
#                                                tweet  sentimen  \
# 0  floran sedang latihan menghapus omnibus law dg...  Negative
# 1  nawww she literally said ngapain demo sih biki...  Negative
# 2  omnibus law di demo ini gaada yg mau demo ppkm...  Negative
# 3  katanya omnibus law buat mempersingkat undangu...  Negative
# 4  koyo demo omnibus lawapa artine gak onok sing ...  Positive
#
#                                         tweet_tokens  \
# 0  [floran, sedang, latihan, menghapus, omnibus, ...
# 1  [nawww, she, literally, said, ngapain, demo, s...
# 2  [omnibus, law, di, demo, ini, gaada, yg, mau, ...
# 3  [katanya, omnibus, law, buat, mempersingkat, u...
# 4  [koyo, demo, omnibus, lawapa, artine, gak, ono...
#
#                                   tweet_tokens_fdist  \
# 0  {'floran': 1, 'sedang': 1, 'latihan': 1, 'meng...
# 1  {'nawww': 1, 'she': 1, 'literally': 1, 'said':...
# 2  {'omnibus': 1, 'law': 1, 'di': 1, 'demo': 2, '...
# 3  {'katanya': 1, 'omnibus': 1, 'law': 1, 'buat':...
# 4  {'koyo': 1, 'demo': 1, 'omnibus': 1, 'lawapa':...
#
#                                     tweet_tokens_WSW  \
# 0  [floran, latihan, menghapus, omnibus, law, mem...
# 1  [nawww, she, literally, said, ngapain, demo, s...
# 2    [omnibus, law, demo, gaada, demo, ppkm, minggu]
# 3  [omnibus, law, mempersingkat, undangundang, la...
# 4  [koyo, demo, omnibus, lawapa, artine, onok, si...
#
#                                     tweet_normalized  \
# 0  [floran, latihan, menghapus, omnibus, law, mem...
# 1  [nawww, she, literally, said, sedang apa, demo...
# 2  [omnibus, law, demo, tidak ada uang, demo, ppk...
# 3  [omnibus, law, mempersingkat, undangundang, la...
# 4  [koyo, demo, omnibus, lawapa, artine, onok, si...
#
#                                 tweet_tokens_stemmed
# 0  [floran, latih, hapus, omnibus, law, blokir, n...
# 1  [nawww, she, literally, said, sedang apa, demo...
# 2  [omnibus, law, demo, tidak ada uang, demo, ppk...
# 3  [omnibus, law, singkat, undangundang, lakok, k...
# 4  [koyo, demo, omnibus, lawapa, artine, onok, si...

# %%
df.to_xlsx('stemming.xlsx',encoding='utf8', index=False)
